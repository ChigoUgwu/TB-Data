# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Code starts here

# %%
df = pd.read_csv('C:/Users/User/Desktop/HHHTB.csv', delimiter=',')

# %%
df
# Out:
#          pid_child                   mx24mq11 mx24mq1_11 mx24mq1_21  \
# 0    1100/1/1/NMIF                        Yes        NaN        NaN
# 1    1101/1/1/BSIF                        Yes        NaN        NaN
# 2    1109/1/1/LSIF                        Yes        NaN        NaN
# 3    1133/1/1/ZMIF  Not done / Not applicable        NaN        NaN
# 4    1142/1/1/NMIF                        Yes        NaN        NaN
# ..             ...                        ...        ...        ...
# 483  3787/1/1/RHIF                        Yes        NaN        NaN
# 484  3792/1/1/NSIF                        Yes        NaN        NaN
# 485  3793/1/1/CMIF                        Yes        NaN        NaN
# 486  3795/1/1/RDIF                        Yes        NaN        NaN
# 487  3796/1/1/EJIF                        Yes        NaN        NaN
#
#      mx24mq2_11  mx24mq2_1_d1  mx24mq2_1_c1 mx24mq2_1_b1 mtx_read1  \
# 0    2016-08-10           NaN           NaN          NaN       Yes
# ...
